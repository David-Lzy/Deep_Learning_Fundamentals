# %%
# Extracting final epoch results for each attention head configuration
final_results = []

for key, df in dataframes.items():
    final_results.append(df.iloc[-1])

# Creating a DataFrame for the final results
final_df = pd.DataFrame(final_results)
# final_df = final_df.reset_index(drop=True)
# final_df["Attention Heads (L)"] = dataframes.keys()
# final_df = final_df.set_index("Attention Heads (L)")
final_df
# Out:
#     Epoch    Loss  Training Accuracy  Testing Accuracy  Evaluation Time
# 49  100.0  0.6762              78.00             28.64            36.62
# 49  100.0  0.7132              77.42             27.66            38.96
# 49  100.0  0.2436              92.09             30.10            35.71
# 49  100.0  0.2733              91.24             36.09            42.80
# 49  100.0  1.2163              65.34             32.04            35.93

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load all the data
directory_path = "./complex"
files = [1, 2, 3, 4, 5]
dataframes = {}

for file in files:
    dataframes[file] = pd.read_csv(f"{directory_path}/{file}.csv")

# Plotting
plt.figure(figsize=(12, 12))
plt.xlim(0, 100)
sns.set_style("whitegrid")

# plt.yscale("log")
# sns.set(font_scale=1.4)

for key, df in dataframes.items():
    sns.lineplot(x=df["Epoch"], y=df["Loss"], label=f"Complexity={key}")

plt.title("Loss over Epochs for Different complexity")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(title="Complexity")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load all the data
directory_path = "./complex"
files = [1, 2, 3, 4, 5]
dataframes = {}

for file in files:
    dataframes[file] = pd.read_csv(f"{directory_path}/{file}.csv")

# Plotting
plt.figure(figsize=(12, 12))
plt.xlim(0, 100)
sns.set_style("whitegrid")

# plt.yscale("log")
# sns.set(font_scale=1.4)

for key, df in dataframes.items():
    sns.lineplot(x=df["Epoch"], y=df["Training Accuracy"], label=f"Complexity={key}")

plt.title("Training Accuracy over Epochs for Different complexity")
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.legend(title="Complexity")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load all the data
directory_path = "./complex"
files = [1, 2, 3, 4, 5]
dataframes = {}

for file in files:
    dataframes[file] = pd.read_csv(f"{directory_path}/{file}.csv")

# Plotting
plt.figure(figsize=(12, 12))
plt.xlim(0, 100)
sns.set_style("whitegrid")


for key, df in dataframes.items():
    sns.lineplot(x=df["Epoch"], y=df["Testing Accuracy"], label=f"Complexity={key}")

plt.title("Testing Accuracy over Epochs for Different complexity")
plt.xlabel("Epoch")
plt.ylabel("Testing Accuracy")
plt.legend(title="Complexity")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load all the data
directory_path = "./complex"
files = [1, 2, 3, 4, 5]
dataframes = {}

for file in files:
    dataframes[file] = pd.read_csv(f"{directory_path}/{file}.csv")

# Plotting
plt.figure(figsize=(12, 12))
plt.xlim(0, 100)
sns.set_style("whitegrid")


for key, df in dataframes.items():
    sns.lineplot(x=df["Epoch"], y=df["Evaluation Time"], label=f"Complexity={key}")

plt.title("Evaluation Time Accuracy over Epochs for Different complexity")
plt.xlabel("Epoch")
plt.ylabel("Evaluation Time")
plt.legend(title="Complexity")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
