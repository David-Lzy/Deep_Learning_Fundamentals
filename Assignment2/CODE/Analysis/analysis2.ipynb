# %%
# Extracting final epoch results for each attention head configuration
final_results = []

for key, df in dataframes.items():
    final_results.append(df.iloc[-1])

# Creating a DataFrame for the final results
final_df = pd.DataFrame(final_results)
# final_df = final_df.reset_index(drop=True)
# final_df["Attention Heads (L)"] = dataframes.keys()
# final_df = final_df.set_index("Attention Heads (L)")
final_df
# Out:
#     Epoch    Loss  Training Accuracy  Testing Accuracy  \
# 49  100.0  0.7250              76.90             27.93
# 49  100.0  0.4730              84.60             30.21
# 49  100.0  0.3186              89.37             33.56
# 49  100.0  0.2069              93.09             35.67
# 49  100.0  0.1080              96.40             39.24
#
#     Evaluation Time (minutes)
# 49                      36.47
# 49                      41.09
# 49                      37.55
# 49                      45.28
# 49                      43.58

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load all the data
directory_path = "./expansion"
files = [1, 2, 4, 8, 16]
dataframes = {}

for file in files:
    dataframes[file] = pd.read_csv(f"{directory_path}/expansion_{file}.csv")

# Plotting
plt.figure(figsize=(12, 12))
plt.xlim(0, 100)
sns.set_style("whitegrid")

# plt.yscale("log")
# sns.set(font_scale=1.4)

for key, df in dataframes.items():
    sns.lineplot(x=df["Epoch"], y=df["Loss"], label=f"expansion={key}")

plt.title("Loss over Epochs for Different Expansions")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(title="Expansion")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load all the data
directory_path = "./expansion"
files = [1, 2, 4, 8, 16]
dataframes = {}

for file in files:
    dataframes[file] = pd.read_csv(f"{directory_path}/expansion_{file}.csv")

# Plotting
plt.figure(figsize=(12, 12))
plt.xlim(0, 100)
# plt.ylim(0.5, df["Training Accuracy"].max())
sns.set_style("whitegrid")

# plt.yscale("log")
# sns.set(font_scale=1.4)

for key, df in dataframes.items():
    sns.lineplot(x=df["Epoch"], y=df["Training Accuracy"], label=f"expansion={key}")

plt.title("Training Accuracy over Epochs for Different expansion")
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.legend(title="expansion")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load all the data
directory_path = "./expansion"
files = [1, 2, 4, 8, 16]
dataframes = {}

for file in files:
    dataframes[file] = pd.read_csv(f"{directory_path}/expansion_{file}.csv")

# Plotting
plt.figure(figsize=(12, 12))
plt.xlim(0, 100)
# plt.ylim(0.5, df["Training Accuracy"].max())
sns.set_style("whitegrid")

# plt.yscale("log")
# sns.set(font_scale=1.4)

for key, df in dataframes.items():
    sns.lineplot(x=df["Epoch"], y=df["Testing Accuracy"], label=f"expansion_={key}")

plt.title("Testing Accuracy over Epochs for Different expansion")
plt.xlabel("Epoch")
plt.ylabel("Testing Accuracy %")
plt.yscale("log")
plt.legend(title="expansion")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load all the data
directory_path = "./expansion"
files = [1, 2, 4, 8, 16]
dataframes = {}

for file in files:
    dataframes[file] = pd.read_csv(f"{directory_path}/expansion_{file}.csv")

# Plotting
plt.figure(figsize=(12, 12))
plt.xlim(0, 100)
# plt.ylim(0.5, df["Training Accuracy"].max())
sns.set_style("whitegrid")

# plt.yscale("log")
# sns.set(font_scale=1.4)

for key, df in dataframes.items():
    sns.lineplot(
        x=df["Epoch"], y=df["Evaluation Time (minutes)"], label=f"expansion={key}"
    )

plt.title("Evaluation Time over Epochs for Different expansion")
plt.xlabel("Epoch")
plt.ylabel("Evaluation Time")
# plt.yscale("log")
plt.legend(title="Evaluation Time")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Extracting final epoch results for each attention head configuration
final_results = []

for key, df in dataframes.items():
    final_results.append(df.iloc[-1])

# Creating a DataFrame for the final results
final_df = pd.DataFrame(final_results)
final_df = final_df.reset_index(drop=True)
# final_df["Attention Heads (L)"] = dataframes.keys()
# final_df = final_df.set_index("Attention Heads (L)")
final_df
# Out:
#    Epoch    Loss  Training Accuracy  Testing Accuracy  \
# 0  100.0  0.7250              76.90             27.93
# 1  100.0  0.4730              84.60             30.21
# 2  100.0  0.3186              89.37             33.56
# 3  100.0  0.2069              93.09             35.67
# 4  100.0  0.1080              96.40             39.24
#
#    Evaluation Time (minutes)
# 0                      36.47
# 1                      41.09
# 2                      37.55
# 3                      45.28
# 4                      43.58
